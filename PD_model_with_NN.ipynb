# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings 
warnings.filterwarnings(action='ignore')

# %%
#  two headers in dataset, skip the extra row
dataset = pd.read_excel('dataset/default-of-credit-card-clients.xls', skiprows=1)

# %%
dataset.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
X = dataset.iloc[:, 1:24].values 
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
'''
    fit_transform vs transform: https://datascience.stackexchange.com/questions/12321/difference-between-fit-and-fit-transform-in-scikit-learn-models
(you have to use the same two parameters μ and σ (values) that you used for centering the training set)
sklearn's transform's fit() just calculates the parameters (e.g. μ and σ)
and saves them as an internal objects state. 
Afterwards, you can call its transform() method to apply the transformation to a particular set of examples.
'''
X_train = sc.fit_transform(X_train) # Fit to data, then transform it.
X_test = sc.transform(X_test) # Perform standardization by centering and scaling

# %%
import keras
from keras.models import Sequential # to initialize ANN
from keras.layers import Dense # to create layers in ANN

# %%
classifier = Sequential()
classifier.add(Dense(units = 12, kernel_initializer = 'uniform', activation = 'relu', input_dim = 23))
classifier.add(Dense(units = 12, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Out:
# 2022-09-06 23:54:00.155922: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 3s 909us/step - loss: 0.4852 - accuracy: 0.7952
# Epoch 2/100
# 2400/2400 [==============================] - 2s 845us/step - loss: 0.4487 - accuracy: 0.8166
# Epoch 3/100
# 2400/2400 [==============================] - 2s 900us/step - loss: 0.4454 - accuracy: 0.8178
# Epoch 4/100
# 2400/2400 [==============================] - 2s 796us/step - loss: 0.4429 - accuracy: 0.8171
# Epoch 5/100
# 2400/2400 [==============================] - 2s 800us/step - loss: 0.4420 - accuracy: 0.8184
# Epoch 6/100
# 2400/2400 [==============================] - 2s 861us/step - loss: 0.4409 - accuracy: 0.8175
# Epoch 7/100
# 2400/2400 [==============================] - 2s 804us/step - loss: 0.4406 - accuracy: 0.8177
# Epoch 8/100
# 2400/2400 [==============================] - 2s 806us/step - loss: 0.4395 - accuracy: 0.8175
# Epoch 9/100
# 2400/2400 [==============================] - 2s 790us/step - loss: 0.4396 - accuracy: 0.8175
# Epoch 10/100
# 2400/2400 [==============================] - 2s 788us/step - loss: 0.4383 - accuracy: 0.8187
# Epoch 11/100
# 2400/2400 [==============================] - 2s 902us/step - loss: 0.4375 - accuracy: 0.8181
# Epoch 12/100
# 2400/2400 [==============================] - 2s 759us/step - loss: 0.4374 - accuracy: 0.8188
# Epoch 13/100
# 2400/2400 [==============================] - 2s 789us/step - loss: 0.4366 - accuracy: 0.8189
# Epoch 14/100
# 2400/2400 [==============================] - 2s 848us/step - loss: 0.4366 - accuracy: 0.8190
# Epoch 15/100
# 2400/2400 [==============================] - 2s 799us/step - loss: 0.4357 - accuracy: 0.8176
# Epoch 16/100
# 2400/2400 [==============================] - 2s 792us/step - loss: 0.4353 - accuracy: 0.8180
# Epoch 17/100
# 2400/2400 [==============================] - 2s 838us/step - loss: 0.4349 - accuracy: 0.8190
# Epoch 18/100
# 2400/2400 [==============================] - 2s 845us/step - loss: 0.4356 - accuracy: 0.8179
# Epoch 19/100
# 2400/2400 [==============================] - 2s 855us/step - loss: 0.4343 - accuracy: 0.8194
# Epoch 20/100
# 2400/2400 [==============================] - 2s 836us/step - loss: 0.4345 - accuracy: 0.8188
# Epoch 21/100
# 2400/2400 [==============================] - 2s 854us/step - loss: 0.4341 - accuracy: 0.8184
# Epoch 22/100
# 2400/2400 [==============================] - 2s 877us/step - loss: 0.4336 - accuracy: 0.8206
# Epoch 23/100
# 2400/2400 [==============================] - 2s 853us/step - loss: 0.4335 - accuracy: 0.8194
# Epoch 24/100
# 2400/2400 [==============================] - 2s 923us/step - loss: 0.4332 - accuracy: 0.8189
# Epoch 25/100
# 2400/2400 [==============================] - 2s 862us/step - loss: 0.4328 - accuracy: 0.8204
# Epoch 26/100
# 2400/2400 [==============================] - 2s 816us/step - loss: 0.4323 - accuracy: 0.8190
# Epoch 27/100
# 2400/2400 [==============================] - 2s 910us/step - loss: 0.4327 - accuracy: 0.8192
# Epoch 28/100
# 2400/2400 [==============================] - 2s 804us/step - loss: 0.4323 - accuracy: 0.8195
# Epoch 29/100
# 2400/2400 [==============================] - 2s 836us/step - loss: 0.4319 - accuracy: 0.8202
# Epoch 30/100
# 2400/2400 [==============================] - 2s 806us/step - loss: 0.4317 - accuracy: 0.8203
# Epoch 31/100
# 2400/2400 [==============================] - 2s 832us/step - loss: 0.4320 - accuracy: 0.8200
# Epoch 32/100
# 2400/2400 [==============================] - 2s 829us/step - loss: 0.4311 - accuracy: 0.8211
# Epoch 33/100
# 2400/2400 [==============================] - 2s 780us/step - loss: 0.4312 - accuracy: 0.8205
# Epoch 34/100
# 2400/2400 [==============================] - 2s 877us/step - loss: 0.4309 - accuracy: 0.8201
# Epoch 35/100
# 2400/2400 [==============================] - 2s 919us/step - loss: 0.4307 - accuracy: 0.8195
# Epoch 36/100
# 2400/2400 [==============================] - 2s 933us/step - loss: 0.4304 - accuracy: 0.8202
# Epoch 37/100
# 2400/2400 [==============================] - 2s 894us/step - loss: 0.4304 - accuracy: 0.8193
# Epoch 38/100
# 2400/2400 [==============================] - 2s 901us/step - loss: 0.4305 - accuracy: 0.8203
# Epoch 39/100
# 2400/2400 [==============================] - 2s 829us/step - loss: 0.4301 - accuracy: 0.8194
# Epoch 40/100
# 2400/2400 [==============================] - 2s 922us/step - loss: 0.4300 - accuracy: 0.8200
# Epoch 41/100
# 2400/2400 [==============================] - 2s 858us/step - loss: 0.4291 - accuracy: 0.8198
# Epoch 42/100
# 2400/2400 [==============================] - 2s 961us/step - loss: 0.4295 - accuracy: 0.8198
# Epoch 43/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4292 - accuracy: 0.8208
# Epoch 44/100
# 2400/2400 [==============================] - 2s 995us/step - loss: 0.4292 - accuracy: 0.8202
# Epoch 45/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4289 - accuracy: 0.8201
# Epoch 46/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4286 - accuracy: 0.8208
# Epoch 47/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4283 - accuracy: 0.8212
# Epoch 48/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4285 - accuracy: 0.8212
# Epoch 49/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4282 - accuracy: 0.8200
# Epoch 50/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4278 - accuracy: 0.8203
# Epoch 51/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4279 - accuracy: 0.8209
# Epoch 52/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4284 - accuracy: 0.8201
# Epoch 53/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4279 - accuracy: 0.8209
# Epoch 54/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4273 - accuracy: 0.8213
# Epoch 55/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4275 - accuracy: 0.8208
# Epoch 56/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4274 - accuracy: 0.8202
# Epoch 57/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4278 - accuracy: 0.8210
# Epoch 58/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4273 - accuracy: 0.8212
# Epoch 59/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4273 - accuracy: 0.8210
# Epoch 60/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4269 - accuracy: 0.8213
# Epoch 61/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4266 - accuracy: 0.8210
# Epoch 62/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4273 - accuracy: 0.8213
# Epoch 63/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4273 - accuracy: 0.8211
# Epoch 64/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4265 - accuracy: 0.8215
# Epoch 65/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4269 - accuracy: 0.8215
# Epoch 66/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4267 - accuracy: 0.8217
# Epoch 67/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4259 - accuracy: 0.8212
# Epoch 68/100
# 2400/2400 [==============================] - 2s 922us/step - loss: 0.4262 - accuracy: 0.8233
# Epoch 69/100
# 2400/2400 [==============================] - 2s 920us/step - loss: 0.4259 - accuracy: 0.8223
# Epoch 70/100
# 2400/2400 [==============================] - 2s 956us/step - loss: 0.4259 - accuracy: 0.8225
# Epoch 71/100
# 2400/2400 [==============================] - 2s 925us/step - loss: 0.4265 - accuracy: 0.8210
# Epoch 72/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4254 - accuracy: 0.8219
# Epoch 73/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4259 - accuracy: 0.8223
# Epoch 74/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4261 - accuracy: 0.8223
# Epoch 75/100
# 2400/2400 [==============================] - 2s 905us/step - loss: 0.4259 - accuracy: 0.8212
# Epoch 76/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4260 - accuracy: 0.8222
# Epoch 77/100
# 2400/2400 [==============================] - 2s 989us/step - loss: 0.4252 - accuracy: 0.8221
# Epoch 78/100
# 2400/2400 [==============================] - 2s 926us/step - loss: 0.4254 - accuracy: 0.8209
# Epoch 79/100
# 2400/2400 [==============================] - 2s 935us/step - loss: 0.4253 - accuracy: 0.8215
# Epoch 80/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4254 - accuracy: 0.8225
# Epoch 81/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4258 - accuracy: 0.8218
# Epoch 82/100
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.4253 - accuracy: 0.8219
# Epoch 83/100
# 2400/2400 [==============================] - 2s 942us/step - loss: 0.4260 - accuracy: 0.8216
# Epoch 84/100
# 2400/2400 [==============================] - 2s 1ms/step - loss: 0.4254 - accuracy: 0.8214
# Epoch 85/100
# 2400/2400 [==============================] - 2s 875us/step - loss: 0.4255 - accuracy: 0.8215
# Epoch 86/100
# 2400/2400 [==============================] - 2s 904us/step - loss: 0.4249 - accuracy: 0.8218
# Epoch 87/100
# 2400/2400 [==============================] - 2s 974us/step - loss: 0.4253 - accuracy: 0.8225
# Epoch 88/100
# 2400/2400 [==============================] - 2s 859us/step - loss: 0.4250 - accuracy: 0.8215
# Epoch 89/100
# 2400/2400 [==============================] - 2s 839us/step - loss: 0.4250 - accuracy: 0.8207
# Epoch 90/100
# 2400/2400 [==============================] - 2s 843us/step - loss: 0.4247 - accuracy: 0.8217
# Epoch 91/100
# 2400/2400 [==============================] - 2s 843us/step - loss: 0.4246 - accuracy: 0.8218
# Epoch 92/100
# 2400/2400 [==============================] - 2s 847us/step - loss: 0.4245 - accuracy: 0.8218
# Epoch 93/100
# 2400/2400 [==============================] - 2s 834us/step - loss: 0.4249 - accuracy: 0.8220
# Epoch 94/100
# 2400/2400 [==============================] - 2s 817us/step - loss: 0.4246 - accuracy: 0.8208
# Epoch 95/100
# 2400/2400 [==============================] - 2s 888us/step - loss: 0.4248 - accuracy: 0.8221
# Epoch 96/100
# 2400/2400 [==============================] - 2s 937us/step - loss: 0.4244 - accuracy: 0.8215
# Epoch 97/100
# 2400/2400 [==============================] - 2s 853us/step - loss: 0.4236 - accuracy: 0.8233
# Epoch 98/100
# 2400/2400 [==============================] - 2s 816us/step - loss: 0.4241 - accuracy: 0.8216
# Epoch 99/100
# 2400/2400 [==============================] - 2s 811us/step - loss: 0.4242 - accuracy: 0.8211
# Epoch 100/100
# 2400/2400 [==============================] - 2s 856us/step - loss: 0.4241 - accuracy: 0.8232

# %%
from keras.models import model_from_json

# serialize model to JSON
model_json = classifier.to_json()
with open("saved-model/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
classifier.save_weights("saved-model/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
json_file = open('saved-model/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("saved-model/model.h5")
print("Loaded model from disk")

# compile loaded model
loaded_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# Loaded model from disk

# %%
y_pred = loaded_model.predict(X_test) # gives probability of defaulting next month
y_pred = (y_pred > 0.5) # choose threshold to convert to true or false
# Out:
# 188/188 [==============================] - 0s 693us/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion matrix: ", cm)
# Out:
# Confusion matrix:  [[4481  222]
#  [ 845  452]]

# %%
correct = cm[0][0] + cm[1][1]
incorrect = cm[0][1] + cm[1][0]
accuracy = (correct) / 6000 
print(accuracy)
# Out:
# 0.8221666666666667
